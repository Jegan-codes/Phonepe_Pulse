# %% [markdown]
# to clone the data from the Phonepe_pulse_repository

# %%
# cloning the phonepe pulse repository
import git
repo_url = "https://github.com/PhonePe/pulse.git"

destination = "E:\GUVI - DS\Phonepe_pulse\data"

from git import Repo

Repo.clone_from(repo_url, destination)

# %% [markdown]
# fetching the data from the aggregate_insurance folder

# %%
import os
import json
import pandas as pd


path = "data/aggregated/insurance/country/india/state/"
Agg_state_list = os.listdir(path)

# print(Agg_state_list)


clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)

Agg_Trans.to_csv("Aggregation_trx.csv")

# %% [markdown]
# fetching the data from the aggregate_transaction folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
#
# path = "data/aggregated/transaction/country/india/state/"
# Agg_state_list = os.listdir(path)
#
# # print(Agg_state_list)
#
#
# clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
#
# for i in Agg_state_list:
#     p_i=path+i+"/"
#     Agg_yr=os.listdir(p_i)
#     for j in Agg_yr:
#         p_j=p_i+j+"/"
#         Agg_yr_list=os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k=p_j+k
#             Data=open(p_k,'r')
#             D=json.load(Data)
#             for z in D['data']['transactionData']:
#               Name=z['name']
#               count=z['paymentInstruments'][0]['count']
#               amount=z['paymentInstruments'][0]['amount']
#               clm['Transacion_type'].append(Name)
#               clm['Transacion_count'].append(count)
#               clm['Transacion_amount'].append(amount)
#               clm['State'].append(i)
#               clm['Year'].append(j)
#               clm['Quater'].append(int(k.strip('.json')))
# #Succesfully created a dataframe
# Agg_Trans=pd.DataFrame(clm)
#
# Agg_Trans.to_csv("Aggregation_trx.csv")

# %% [markdown]
# fetching the data from the aggregate_user folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
#
# path = "data/aggregated/user/country/india/state/"
# Agg_state_list = os.listdir(path)
#
# # print(Agg_state_list)
#
#
# clm={'State':[], 'Year':[],'Quater':[],'Brand':[], 'User_count':[], 'User_percentage':[]}
#
# for i in Agg_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             with open(p_k, 'r') as Data:
#                 D = json.load(Data)
#
#                 # Ensure usersByDevice exists
#                 if 'usersByDevice' in D['data'] and D['data']['usersByDevice']:
#                     for z in D['data']['usersByDevice']:
#                         clm['Brand'].append(z['brand'])
#                         clm['User_count'].append(z['count'])
#                         clm['User_percentage'].append(z['percentage'])
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
# #Succesfully created a dataframe
# Agg_Trans=pd.DataFrame(clm)
#
# Agg_Trans.to_csv("Aggregation_user.csv")

# %% [markdown]
# Fetching the data from the map_insurance

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# path = "data/map/insurance/country/india/state/"
# Map_state_list = os.listdir(path)
#
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Latitude': [], 'Longitude': [], 'Metric': [], 'Label': []
# }
#
# for i in Map_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             with open(p_k, 'r', encoding='utf-8') as Data:
#                 D = json.load(Data)
#
#                 # ✅ Correct path to reach list of rows
#                 try:
#                     rows = D['data']['data']['data']
#                 except KeyError:
#                     print(f"Skipping {p_k} – wrong structure")
#                     continue
#
#                 for row in rows:
#                     if isinstance(row, list) and len(row) == 4:
#                         clm['Latitude'].append(row[0])
#                         clm['Longitude'].append(row[1])
#                         clm['Metric'].append(row[2])
#                         clm['Label'].append(row[3])
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
# # Create dataframe and export to CSV
# Map_Trans = pd.DataFrame(clm)
# Map_Trans.to_csv("Map_Insurance.csv")
# print("CSV successfully created.")

# %% [markdown]
# Fetching the data from the Map_ins_hover

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/map/insurance/hover/country/india/state/"
# Map_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Transaction_count': [], 'Transaction_amount': []
# }
#
# # Traverse through the folder structure
# for i in Map_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             try:
#                 with open(p_k, 'r', encoding='utf-8') as Data:
#                     D = json.load(Data)
#
#                     # Correctly loop through hoverDataList
#                     for z in D['data']['hoverDataList']:
#                         name = z['name']
#                         count = z['metric'][0]['count']
#                         amount = z['metric'][0]['amount']
#
#                         clm['Transaction_area'].append(name)
#                         clm['Transaction_count'].append(count)
#                         clm['Transaction_amount'].append(amount)
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
#             except Exception as e:
#                 print(f"Error reading file {p_k}: {e}")
#
# # Create the DataFrame
# Map_Trans = pd.DataFrame(clm)
#
# # Save to CSV
# Map_Trans.to_csv("Map_Ins_hover.csv")
#
# print("File created successfully")

# %% [markdown]
# Fetching data from map_transaction folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/map/transaction/hover/country/india/state"
# Map_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Transaction_count': [], 'Transaction_amount': []
# }
#
# # Traverse through the folder structure
# for i in Map_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             Data = open(p_k,'r')
#             D = json.load(Data)
#             for z in D['data']['hoverDataList']:
#                         name = z['name']
#                         count = z['metric'][0]['count']
#                         amount = z['metric'][0]['amount']
#
#                         clm['Transaction_area'].append(name)
#                         clm['Transaction_count'].append(count)
#                         clm['Transaction_amount'].append(amount)
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
#
# # Create the DataFrame
# Map_Trans = pd.DataFrame(clm)
#
# # Save to CSV
# Map_Trans.to_csv("Map_transaction.csv")
#
# print("File created successfully")

# %% [markdown]
# Fetching data from the Map_users folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/map/user/hover/country/india/state"
# Map_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Registered_Users': [], 'App_opens': []
# }
#
# # Traverse through the folder structure
# for i in Map_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             Data = open(p_k,'r')
#             D = json.load(Data)
#
#             hover_data = D['data']['hoverData']
#
#             for state_name, values in hover_data.items():
#                         clm['Transaction_area'].append(state_name)
#                         clm['Registered_Users'].append(values.get('registeredUsers', 0))
#                         clm['App_opens'].append(values.get('appOpens', 0))
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
#
# # Create the DataFrame
# Map_Trans = pd.DataFrame(clm)
#
# # Save to CSV
# Map_Trans.to_csv("Map_User.csv")
#
# print("File created successfully")

# %% [markdown]
# Fetching data fromm the Top Insurance folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/top/insurance/country/india/state"
# Top_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Transaction_count': [], 'Transaction_amount': []
# }
#
# # Traverse through the folder structure
# for i in Top_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             Data = open(p_k,'r')
#             D = json.load(Data)
#
#             data_list = None
#             if D['data']['districts'] is not None and len(D['data']['districts']) > 0:
#                 data_list = D['data']['districts']
#             elif D['data']['pincodes'] is not None and len(D['data']['pincodes']) > 0:
#                 data_list = D['data']['pincodes']
#             elif D['data']['states'] is not None and len(D['data']['states']) > 0:
#                 data_list = D['data']['states']
#
#             if data_list is not None:
#                 for z in data_list:
#                     name = z['entityName']
#                     # Access count and amount directly from the metric dictionary
#                     if z['metric'] is not None: # Check if metric is not None
#                         count = z['metric']['count']
#                         amount = z['metric']['amount']
#
#                         clm['Transaction_area'].append(name)
#                         clm['Transaction_count'].append(count)
#                         clm['Transaction_amount'].append(amount)
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
#
# # Create the DataFrame
# Top_Ins = pd.DataFrame(clm)
#
# # Save to CSV
# Top_Ins.to_csv("Top_Insurance.csv")
#
# print("File created successfully")

# %% [markdown]
# Fetching data from the Top Transaction folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/top/transaction/country/india/state"
# Top_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Transaction_count': [], 'Transaction_amount': []
# }
#
# # Traverse through the folder structure
# for i in Top_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             Data = open(p_k,'r')
#             D = json.load(Data)
#
#             data_list = None
#             if D['data']['districts'] is not None and len(D['data']['districts']) > 0:
#                 data_list = D['data']['districts']
#             elif D['data']['pincodes'] is not None and len(D['data']['pincodes']) > 0:
#                 data_list = D['data']['pincodes']
#             elif D['data']['states'] is not None and len(D['data']['states']) > 0:
#                 data_list = D['data']['states']
#
#             if data_list is not None:
#                 for z in data_list:
#                     name = z['entityName']
#                     # Access count and amount directly from the metric dictionary
#                     if z['metric'] is not None: # Check if metric is not None
#                         count = z['metric']['count']
#                         amount = z['metric']['amount']
#
#                         clm['Transaction_area'].append(name)
#                         clm['Transaction_count'].append(count)
#                         clm['Transaction_amount'].append(amount)
#                         clm['State'].append(i)
#                         clm['Year'].append(j)
#                         clm['Quater'].append(int(k.strip('.json')))
#
#
# # Create the DataFrame
# Top_Trans = pd.DataFrame(clm)
#
# # Save to CSV
# Top_Trans.to_csv("Top_transaction.csv")
#
# print("File created successfully")

# %% [markdown]
# fetching data from the Top Users folder

# %% [markdown]
# import os
# import json
# import pandas as pd
#
# # Define the path
# path = "data/top/user/country/india/state"
# Top_state_list = os.listdir(path)
#
# # Initialize the dictionary for the dataframe
# clm = {
#     'State': [], 'Year': [], 'Quater': [],
#     'Transaction_area': [], 'Registered_Users': []
# }
#
# # Traverse through the folder structure
# for i in Top_state_list:
#     p_i = os.path.join(path, i)
#     Agg_yr = os.listdir(p_i)
#     for j in Agg_yr:
#         p_j = os.path.join(p_i, j)
#         Agg_yr_list = os.listdir(p_j)
#         for k in Agg_yr_list:
#             p_k = os.path.join(p_j, k)
#             Data = open(p_k,'r')
#             D = json.load(Data)
#
#             data_list = None
#             if D['data']['districts'] is not None and len(D['data']['districts']) > 0:
#                 data_list = D['data']['districts']
#             elif D['data']['pincodes'] is not None and len(D['data']['pincodes']) > 0:
#                 data_list = D['data']['pincodes']
#             elif D['data']['states'] is not None and len(D['data']['states']) > 0:
#                 data_list = D['data']['states']
#
#             if data_list is not None:
#                 for z in data_list:
#                     # Access name and registeredUsers directly
#                     name = z['name']
#                     count = z['registeredUsers']
#
#                     clm['Transaction_area'].append(name)
#                     clm['Registered_Users'].append(count)
#                     clm['State'].append(i)
#                     clm['Year'].append(j)
#                     clm['Quater'].append(int(k.strip('.json')))
#
#
# # Create the DataFrame
# Top_User = pd.DataFrame(clm)
#
# # Save to CSV
# Top_User.to_csv("Top_User.csv")
#
# print("File created successfully")

# %% [markdown]
# **Pushing the data to the Database**

# %% [markdown]
# For the Agrregated Insurance Table

# %% [markdown]
# import pandas as pd
# import psycopg2
# #import requests
# from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
#
# # connection to existing db in postgresql
# # connection = psycopg2.connect(
# #                                 host = "localhost",
# #                                 port = 5432,
# #                                 user = "postgres",
# #                                 password = "jegan",
# #                                 database = "postgres" )
#
# # connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
#
# # # creating phonepe db
# # cursor = connection.cursor()
# # cursor.execute("create database Phonepe_pulse_db")
# # cursor.close()
# # connection.close()
#
# # connect to phonepe db
# connection = psycopg2.connect(
#                               host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 database = "phonepe_pulse_db",
#                                 password = "jegan" )
#
# # table creation
# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
#
# cursor = connection.cursor()
# cursor.execute("""create table if not exists Aggregation_ins (State text, Year int, Quater int, Transacion_type text, Transacion_count int, Transacion_amount bigint)""")
#
# df = pd.read_csv("Aggregated_ins.csv")
# for index, row in df.iterrows():
#     cursor.execute("""
#         INSERT INTO Aggregation_ins (State, Year, Quater, transacion_type, transacion_count, transacion_amount)
#         VALUES (%s, %s, %s, %s, %s, %s)
#     """, (
#         row['State'],
#         row['Year'],
#         row['Quater'],
#         row['Transacion_type'],
#         row['Transacion_count'],
#         row['Transacion_amount']
#     ))
#
# connection.commit()
# cursor.close()
# print("table created succesfully")

# %% [markdown]
# For the Aggregated Transaction table

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists Aggregation_trx (State text, Year int, Quater int, Transacion_type text, Transacion_count bigint, Transacion_amount numeric(30,0))""")

df = pd.read_csv("Aggregation_trx.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO Aggregation_ins (State, Year, Quater, Transacion_type, Transacion_count, Transacion_amount)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transacion_type'],
        row['Transacion_count'],
        row['Transacion_amount']
    ))

connection.commit()
cursor.close()
print("table created succesfully")

# %% [markdown]
# For the Aggregation Users Table

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists Aggregation_user (State text, Year int, Quater int, Brand text, User_count int, User_percentage float)""")

df = pd.read_csv("Aggregation_user.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO Aggregation_user (State, Year, Quater, Brand, User_count, User_percentage)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Brand'],
        row['User_count'],
        row['User_percentage']
    ))

connection.commit()
cursor.close()
print("table created succesfully")

# %% [markdown]
# For the Map Insurance hover table

# %% [markdown]
# import pandas as pd
# import psycopg2
# #import requests
# from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
#
# # connection to existing db in postgresql
# # connection = psycopg2.connect(
# #                                 host = "localhost",
# #                                 port = 5432,
# #                                 user = "postgres",
# #                                 password = "jegan",
# #                                 database = "postgres" )
#
# # connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
#
# # # creating phonepe db
# # cursor = connection.cursor()
# # cursor.execute("create database Phonepe_pulse_db")
# # cursor.close()
# # connection.close()
#
# # connect to phonepe db
# connection = psycopg2.connect(
#                               host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 database = "phonepe_pulse_db",
#                                 password = "jegan" )
#
# # table creation
# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
#
# cursor = connection.cursor()
# cursor.execute("""create table if not exists Map_Ins_hover (State text, Year int, Quater int, Transaction_area text, Transaction_count int, Transaction_amount bigint)""")
#
# df = pd.read_csv("Map_Ins_hover.csv")
# for index, row in df.iterrows():
#     cursor.execute("""
#         INSERT INTO Map_Ins_hover (State, Year, Quater, Transaction_area, Transaction_count, Transaction_amount)
#         VALUES (%s, %s, %s, %s, %s, %s)
#     """, (
#         row['State'],
#         row['Year'],
#         row['Quater'],
#         row['Transaction_area'],
#         row['Transaction_count'],
#         row['Transaction_amount']
#     ))
#
# connection.commit()
# cursor.close()
# print("table created succesfully")

# %% [markdown]
# For the table of Map Isurance

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists Map_Insurance (State text, Year int, Quater int, Latitude float, Longitude float, Metric int, Label text)""")

df = pd.read_csv("Map_Insurance.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO Map_Insurance (State, Year, Quater, Latitude, Longitude, Metric, Label)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Latitude'],
        row['Longitude'],
        row['Metric'],
        row['Label']
    ))

connection.commit()
cursor.close()
print("table created succesfully")

# %% [markdown]
# For the Table - Map_Transaction

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
# cursor.execute("DROP TABLE IF EXISTS top_user")
cursor.execute("""create table if not exists map_transaction (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        transaction_count BIGINT,
        transaction_amount BIGINT)""")

df = pd.read_csv("Map_transaction.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO map_transaction (state, year, quater, transaction_area, transaction_count, transaction_amount)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['Transaction_count'],
        row['Transaction_amount']
    ))

connection.commit()
cursor.close()
print("Map_transaction table created succesfully")

# %% [markdown]
# For the table Map_Users

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("DROP TABLE IF EXISTS map_users")
cursor.execute("""create table if not exists map_Users (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        registered_users BIGINT,
        app_opens BIGINT)""")

df = pd.read_csv("Map_User.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO map_Users (state, year, quater, transaction_area, registered_Users, app_opens)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['Registered_Users'],
        row['App_opens']
    ))

connection.commit()
cursor.close()
print("Map_User table created succesfully")

# %% [markdown]
# For the Table - Top_Insurance

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists top_insurance (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        transaction_count BIGINT,
        transaction_amount BIGINT)""")

df = pd.read_csv("Top_Insurance.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO top_insurance (state, year, quater, transaction_area, transaction_count, transaction_amount)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['Transaction_count'],
        row['Transaction_amount']
    ))

connection.commit()
cursor.close()
print("Top_Insurance table created succesfully")

# %% [markdown]
# For the Table - Top_Transaction

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists top_transaction (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        transaction_count BIGINT,
        transaction_amount BIGINT)""")

df = pd.read_csv("Top_transaction.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO top_transaction (state, year, quater, transaction_area, transaction_count, transaction_amount)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['Transaction_count'],
        row['Transaction_amount']
    ))

connection.commit()
cursor.close()
print("Top_transaction table created succesfully")

# %% [markdown]
# For the Table - Top_Users

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("""create table if not exists top_user (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        registered_users BIGINT)""")

df = pd.read_csv("Top_User.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO top_user (state, year, quater, transaction_area, registerted_users)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['registered_users']
    ))

connection.commit()
cursor.close()
print("Top_User table created succesfully")

# %% [markdown]
# For the Table - Top_User

# %%
import pandas as pd
import psycopg2
#import requests
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# connection to existing db in postgresql
# connection = psycopg2.connect(
#                                 host = "localhost",
#                                 port = 5432,
#                                 user = "postgres",
#                                 password = "jegan",
#                                 database = "postgres" )

# connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# # creating phonepe db
# cursor = connection.cursor()
# cursor.execute("create database Phonepe_pulse_db")
# cursor.close()
# connection.close()

# connect to phonepe db
connection = psycopg2.connect(
                              host = "localhost",
                                port = 5432,
                                user = "postgres",
                                database = "phonepe_pulse_db",
                                password = "jegan" )

# table creation
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = connection.cursor()
cursor.execute("DROP TABLE IF EXISTS top_user")
cursor.execute("""create table if not exists top_user (state TEXT,
        year INT,
        quater INT,
        transaction_area TEXT,
        registered_users BIGINT)""")

df = pd.read_csv("Top_User.csv")
for index, row in df.iterrows():
    cursor.execute("""
        INSERT INTO top_user (state, year, quater, transaction_area, registered_users)
        VALUES (%s, %s, %s, %s, %s)
    """, (
        row['State'],
        row['Year'],
        row['Quater'],
        row['Transaction_area'],
        row['Registered_Users']
    ))

connection.commit()
cursor.close()
print("Top_User table created succesfully")
